# %%
import nasdaqdatalink
mydata = nasdaqdatalink.get("FRED/GDP")

# %%
mydata
# Out:
#                 Value
# Date
# 1947-01-01    243.164
# 1947-04-01    245.968
# 1947-07-01    249.585
# 1947-10-01    259.745
# 1948-01-01    265.742
# ...               ...
# 2020-10-01  21477.597
# 2021-01-01  22038.226
# 2021-04-01  22740.959
# 2021-07-01  23202.344
# 2021-10-01  23992.355
#
# [300 rows x 1 columns]

# %%
j = mydata.to_json()

# %%
for idx, row in mydata.iterrows():
    print("[" + str(idx.timestamp() * 1000) + ", " + str(row['Value']) + "],")
# Out:
# [-725846400000.0, 243.164],
# [-718070400000.0, 245.968],
# [-710208000000.0, 249.585],
# [-702259200000.0, 259.745],
# [-694310400000.0, 265.742],
# [-686448000000.0, 272.567],
# [-678585600000.0, 279.196],
# [-670636800000.0, 280.366],
# [-662688000000.0, 275.034],
# [-654912000000.0, 271.351],
# [-647049600000.0, 272.889],
# [-639100800000.0, 270.627],
# [-631152000000.0, 280.828],
# [-623376000000.0, 290.383],
# [-615513600000.0, 308.153],
# [-607564800000.0, 319.945],
# [-599616000000.0, 336.0],
# [-591840000000.0, 344.09],
# [-583977600000.0, 351.385],
# [-576028800000.0, 356.178],
# [-568080000000.0, 359.82],
# [-560217600000.0, 361.03],
# [-552355200000.0, 367.701],
# [-544406400000.0, 380.812],
# [-536457600000.0, 387.98],
# [-528681600000.0, 391.749],
# [-520819200000.0, 391.171],
# [-512870400000.0, 385.97],
# [-504921600000.0, 385.345],
# [-497145600000.0, 386.121],
# [-489283200000.0, 390.996],
# [-481334400000.0, 399.734],
# [-473385600000.0, 413.073],
# ...

# %%
j
with open("j.json", "w") as outfile:
    outfile.write(j)
